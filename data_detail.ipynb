# %%
import chromedriver_binary
from selenium import webdriver
from time import sleep
import openpyxl
import pandas as pd

from scraping_detail_data import Sucraping_detail

# %%
detail = Sucraping_detail()

# %%
detail.get_years()
# Out:
# ['https://www.kenchikukyo.jp/schedule/year/2022/',
#  'https://www.kenchikukyo.jp/schedule/year/2021/',
#  'https://www.kenchikukyo.jp/schedule/year/2020/']

# %%
df = detail.get_detail_data()

# %%
df
# Out:
# 2       入場  品種   名号   期待育種価        耳標番号 資格  性別   生年月日   日令    父牛  ...    得点  \
# 0        1  黒毛   清姫     NaN  1585213779  登  去勢  44380  278   福之姫  ...  82.4
# 1        2  黒毛  なつみ     NaN  1585213847  登   雌  44367  291   福之姫  ...  80.2
# 2        3  黒毛  かなみ  AAACAA  1585214479  登   雌  44387  271   福之姫  ...  81.3
# 3        4  黒毛   さき  BABCBA  1585213557  登   雌  44361  297  美津照重  ...  80.8
# 4        5  黒毛   隆福  AAACAA  1585214356  登  去勢  44406  252   福之姫  ...  81.7
# ...    ...  ..  ...     ...         ... ..  ..    ...  ...   ...  ...   ...
# 29985  573  黒毛  みちえ     NaN  1613815371  登   雌  43998  269  美津照重  ...  82.1
# 29986  574  黒毛  ちよこ  BABBAA  1613815395  登   雌  44010  257    福増  ...  82.4
# 29987  575  黒毛   福平  ACACCB  1391689461  登  去勢  43971  296   秋忠平  ...  82.1
# 29988  576  黒毛   はな     NaN  1432684530  登   雌  43984  283   花久勝  ...  82.1
# 29989  581  黒毛  くおん     NaN  1587285828  登   雌  43936  331   華春久  ...  80.2
#
# ...

# %%
df.columns
# Out:
# Index(['入場', '品種', '名号', '期待育種価', '耳標番号', '資格', '性別', '生年月日', '日令', '父牛',
#        '母の父', '母の祖父', '母の祖々父', '母牛名号', '母資格', '登録番号', '得点', '母牛生年', '産次',
#        '備考1', '備考2', '生産者住所', '氏名', '主要飼料名1', '主要飼料名2', '主要飼料名3'],
#       dtype='object', name=2)
